# %%
import pandas as pd
import numpy as np

# %%
data_path = "/Users/kevinmbp/Desktop/2D_spec_dict/data/short_peptide/deconv/VEA3+_annotated.txt"
data = pd.read_csv(data_path, sep = '\t')

# %%
data = data[data['Ranking'] != -1]
data = data.sort_values('Ranking')
contain = data[data['Ranking'] == 48]
contain
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 94  187.072039  596.845575  16964459.0    15695268.0  410.93859       48
# 95  596.845575  187.072039  16964459.0    15695268.0  410.93859       48
#
#     charge_A  envelope_id_A  monoisotopic_mass_A  deconvoluted_mz_A  charge_B  \
# 94         1            539             186.0648           187.0720         2
# 95         2           9974            1191.6766          1192.6839         1
#
#     envelope_id_B  monoisotopic_mass_B  deconvoluted_mz_B
# 94          10020            1191.6766          1192.6839
# 95            531             186.0648           187.0720

# %%
data_path = "/Users/kevinmbp/Desktop/2D_spec_dict/data/short_peptide/deconv/VEA3+_annotated.txt"
data = pd.read_csv(data_path, sep = '\t')
non_contain = data[data['Ranking'] == 48]
non_contain
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 94  187.072039  596.845575  16964459.0    15695268.0  410.93859       48
# 95  596.845575  187.072039  16964459.0    15695268.0  410.93859       48
#
#     charge_A  envelope_id_A  monoisotopic_mass_A  deconvoluted_mz_A  charge_B  \
# 94         1            539             186.0648           187.0720         2
# 95         2           9974            1191.6766           596.8456         1
#
#     envelope_id_B  monoisotopic_mass_B  deconvoluted_mz_B
# 94          10020            1191.6766           596.8456
# 95            531             186.0648           187.0720

# %%
data_path = "/Users/kevinmbp/Desktop/2D_spec_dict/data/short_peptide/deconv/VEA3+_annotated.txt"
data = pd.read_csv(data_path, sep = '\t')
non_contain = data[data['Ranking'] == 7]
non_contain
# Out:
#           m/z A        m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 12  1008.563901   371.193813  18755287.0    18322403.0  908.68617        7
# 13   371.193813  1008.563901  18755287.0    18322403.0  908.68617        7
#
#     charge_A  envelope_id_A  monoisotopic_mass_A  deconvoluted_mz_A  charge_B  \
# 12         1          15832            1007.5566          1008.5639         1
# 13         1           2798             370.1865           371.1938         1
#
#     envelope_id_B  monoisotopic_mass_B  deconvoluted_mz_B
# 12           2769             370.1865           371.1938
# 13          15897            1007.5566          1008.5639

# %%
non_contain = data[data['Ranking'] == 9]
non_contain
# Out:
#          m/z A       m/z B   Covariance  Partial Cov.      Score  Ranking  \
# 16  596.845575  415.183883  140359140.0   117995480.0  856.04609        9
# 17  415.183883  596.845575  140359140.0   117995480.0  856.04609        9
#
#     charge_A  envelope_id_A  monoisotopic_mass_A  deconvoluted_mz_A  charge_B  \
# 16         2          10033            1191.6766           596.8456         1
# 17         1           4234             414.1766           415.1839         2
#
#     envelope_id_B  monoisotopic_mass_B  deconvoluted_mz_B
# 16           4241             414.1766           415.1839
# 17           9886            1191.6766           596.8456

# %%
df_msms = pd.read_csv(
    "/Users/kevinmbp/Desktop/2D_spec_dict/data/virtual_MSMS/VEADIAGHGQEVLIR-mz536-z3_Intensity_Sum",
    sep=r"\s+",
    header=None,
    names=["intensity", "mz", "error", "annotation"],
    engine="python",
    usecols=[0, 1, 2, 3]
)

# %%
df_msms.head()
# Out:
#      intensity          mz        error annotation
# 0   968.253174  156.102426 -1000.000000         No
# 1  8633.249023  175.119605    -0.000653         y1
# 2  6728.792969  183.113388    -0.000584  b2-H2O-CO
# 3   973.557800  187.072039    -0.000706   internal
# 4  1063.230103  195.088350    -0.000698   internal

# %%
data[data['Ranking'] == 3]
# Out:
#         m/z A       m/z B   Covariance  Partial Cov.      Score  Ranking  \
# 4  300.156407  654.359227  355823770.0   262187790.0  1054.3404        3
# 5  654.359227  300.156407  355823770.0   262187790.0  1054.3404        3
#
#    charge_A  envelope_id_A  monoisotopic_mass_A  deconvoluted_mz_A  charge_B  \
# 4         1           2588             299.1491           300.1564         2
# 5         2          11590            1305.7356           653.8751         1
#
#    envelope_id_B  monoisotopic_mass_B  deconvoluted_mz_B
# 4          11580            1305.7356           653.8751
# 5           2557             299.1491           300.1564

# %%
data[data['Ranking'] == 6]
# Out:
#          m/z A       m/z B   Covariance  Partial Cov.      Score  Ranking  \
# 10  300.156407  654.860832  194805700.0   152553350.0  913.39267        6
# 11  654.860832  300.156407  194805700.0   152553350.0  913.39267        6
#
#     charge_A  envelope_id_A  monoisotopic_mass_A  deconvoluted_mz_A  charge_B  \
# 10         1           2452             299.1491           300.1564         2
# 11         2          11432            1305.7356           653.8751         1
#
#     envelope_id_B  monoisotopic_mass_B  deconvoluted_mz_B
# 10          11580            1305.7356           653.8751
# 11           2589             299.1491           300.1564

# %%
data[data['Ranking'] ==44]
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 86  655.362039  300.156407  38377238.0    30956076.0  419.96469       44
# 87  300.156407  655.362039  38377238.0    30956076.0  419.96469       44
#
#     charge_A  envelope_id_A  monoisotopic_mass_A  deconvoluted_mz_A  charge_B  \
# 86         2          11465            1305.7356           653.8751         1
# 87         1           2457             299.1491           300.1564         2
#
#     envelope_id_B  monoisotopic_mass_B  deconvoluted_mz_B
# 86           2503             299.1491           300.1564
# 87          11471            1305.7356           653.8751

# %%
df_msms[(df_msms['mz'] <= (655.362039 + 2)) & (df_msms['mz'] >= (655.362039 - 2))]
# Out:
#          intensity          mz        error annotation
# 106    1106.595581  653.875096 -1000.000000         No
# 107  108949.343750  654.359227    -0.002276        y12
# 108   48794.230469  654.860832    -0.002204        y12
# 109    9481.617188  655.362039 -1000.000000         No

# %%
sum(df_msms['intensity'] < 655.362039 + 1)
# Out:
# 0

# %%
data_path = "/Users/kevinmbp/Desktop/2D_spec_dict/data/short_peptide/deconv/VEA3+intensity_annotated.txt"
df = pd.read_csv(data_path, sep="\t", engine="python")
df[(df['Ranking'] == 3)][['m/z A', 'm/z B', 'deconvoluted_mz_A', 'intensity A']]
# Out:
#         m/z A       m/z B  deconvoluted_mz_A    intensity A
# 4  300.156407  654.359227           299.1531   33528.605469
# 5  654.359227  300.156407           654.3592  108949.343750

# %%
df[(df['envelope_id_A'] == 2588) | (df['envelope_id_B'] == 2588)]
# Out:
#             m/z A       m/z B    Covariance  Partial Cov.        Score  \
# 4      300.156407  654.359227  3.558238e+08  2.621878e+08  1054.340400
# 12152  428.215597  300.156407  8.304274e+05  5.946674e+04     3.454600
# 12594  536.242818  301.159861  0.000000e+00  0.000000e+00     0.000000
# 19420  301.159861  399.225909 -2.196001e+05 -2.366732e+05   -60.965164
#
#        Ranking   intensity A    intensity B  charge_A  envelope_id_A  \
# 4            3  33528.605469  108949.343750         1           2588
# 12152     6077   1113.214722   33528.605469         1           4512
# 12594     6298    777.040710    2384.458984         1           9115
# 19420     9711   2384.458984     941.856201         1           2588
#
#        monoisotopic_mass_A  deconvoluted_mz_A  isotope_similarity_A  charge_B  \
# 4                 298.1458           299.1531                0.9985         2
# 12152             428.1922           429.1995                1.0000         1
# ...

# %%
df[(df['Ranking'] == 12)]
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 22  528.268562  540.303260  82621553.0    72492860.0  769.61895       12
# 23  540.303260  528.268562  82621553.0    72492860.0  769.61895       12
#
#      intensity A   intensity B  charge_A  envelope_id_A  monoisotopic_mass_A  \
# 22   5624.222656  81014.875000         1           8295             529.2806
# 23  81014.875000   5624.222656         2           9242            1077.5886
#
#     deconvoluted_mz_A  isotope_similarity_A  charge_B  envelope_id_B  \
# 22           530.2879                0.9924         2           9173
# 23           539.8016                0.9993         1           8141
#
#     monoisotopic_mass_B  deconvoluted_mz_B  isotope_similarity_B
# 22            1077.5886           539.8016                0.9993
# 23             529.2806           530.2879                0.9924

# %%
df[(df['envelope_id_A'] == 8295)]
# Out:
#             m/z A       m/z B   Covariance  Partial Cov.       Score  Ranking  \
# 22     528.268562  540.303260  82621553.00   72492860.00  769.618950       12
# 6609   529.270973  371.193813    336664.71     286388.87   56.858449     3305
# 12989  530.287900  536.242818         0.00          0.00    0.000000     6495
# 14361  532.294456  814.482029    209076.66    -183141.15  -10.378494     7181
# 20929  531.286332  501.360683   -359860.19    -486401.05  -78.552677    10465
#
#         intensity A   intensity B  charge_A  envelope_id_A  \
# 22      5624.222656  81014.875000         1           8295
# 6609    1108.264771   2637.109131         1           8295
# 12989  12948.754883    777.040710         1           8295
# 14361    750.020203  21098.802734         1           8295
# 20929   2229.270752   1174.901367         1           8295
#
#        monoisotopic_mass_A  deconvoluted_mz_A  isotope_similarity_A  charge_B  \
# ...

# %%
df[(df['Ranking'] == 19)]
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 36  951.541865  428.215597   7178952.0     7105385.0  662.22646       19
# 37  428.215597  951.541865   7178952.0     7105385.0  662.22646       19
#
#     intensity A  intensity B  charge_A  envelope_id_A  monoisotopic_mass_A  \
# 36  4298.900879  1113.214722         1          15497             949.5312
# 37  1113.214722  4298.900879         1           4523             428.1922
#
#     deconvoluted_mz_A  isotope_similarity_A  charge_B  envelope_id_B  \
# 36           950.5385                   1.0         1           4657
# 37           429.1995                   1.0         1          15538
#
#     monoisotopic_mass_B  deconvoluted_mz_B  isotope_similarity_B
# 36             428.1922           429.1995                   1.0
# 37             949.5312           950.5385                   1.0

# %%
df[(df['envelope_id_A'] == 15497)]
# Out:
#            m/z A       m/z B  Covariance  Partial Cov.       Score  Ranking  \
# 36    951.541865  428.215597   7178952.0     7105385.0  662.226460       19
# 4397  952.544553  746.395337   1167766.8     1064822.7   84.295705     2199
#
#       intensity A  intensity B  charge_A  envelope_id_A  monoisotopic_mass_A  \
# 36    4298.900879  1113.214722         1          15497             949.5312
# 4397  1306.884277  4973.362305         1          15497             949.5312
#
#       deconvoluted_mz_A  isotope_similarity_A  charge_B  envelope_id_B  \
# 36             950.5385                   1.0         1           4657
# 4397           950.5385                   1.0         2          14171
#
#       monoisotopic_mass_B  deconvoluted_mz_B  isotope_similarity_B
# 36               428.1922           429.1995                1.0000
# 4397            1487.7710           744.8928                0.9976

# %%
data_path = "/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/deconv/HAD4+intensity_annotated.txt"
df = pd.read_csv(data_path, sep="\t", engine="python")
df[(df['Ranking'] == 1)][['m/z A', 'm/z B', 'deconvoluted_mz_A', 'intensity A', 'deconvoluted_mz_B', 'intensity B']]
# Out:
#         m/z A        m/z B  deconvoluted_mz_A  intensity A  deconvoluted_mz_B  \
# 0  476.274275  1097.865943           476.2743   98392.0625          1097.5315
#
#      intensity B
# 0  128894.265625

# %%
df[(df['Ranking'] == 244)]
# Out:
#           m/z A        m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 243  209.104503  1186.587663   8454.6122     8432.5908  228.87577      244
#
#      intensity A  intensity B  charge_A  envelope_id_A  monoisotopic_mass_A  \
# 243  3655.753662  1083.544067         1             25             208.0972
#
#      deconvoluted_mz_A  isotope_similarity_A  charge_B  envelope_id_B  \
# 243           209.1045                   NaN         3            575
#
#      monoisotopic_mass_B  deconvoluted_mz_B  isotope_similarity_B
# 243            3555.7421          1186.2546                0.9965

# %%
df[(df['envelope_id_B'] == 575)]
# Out:
#            m/z A        m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 243   209.104503  1186.587663   8454.6122     8432.5908  228.87577      244
# 1074  760.335250  1186.923542   9364.2978     9206.0100  151.48949     1075
#
#       intensity A  intensity B  charge_A  envelope_id_A  monoisotopic_mass_A  \
# 243   3655.753662  1083.544067         1             25             208.0972
# 1074  7126.022949  1370.823364         1            526             759.3280
#
#       deconvoluted_mz_A  isotope_similarity_A  charge_B  envelope_id_B  \
# 243            209.1045                   NaN         3            575
# 1074           760.3352                   NaN         3            575
#
#       monoisotopic_mass_B  deconvoluted_mz_B  isotope_similarity_B
# 243             3555.7421          1186.2546                0.9965
# 1074            3555.7421          1186.2546                0.9965

# %%
data_path = "/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/deconv/HAD4_ffc_annotated.txt"
df = pd.read_csv(data_path, sep="\t", engine="python")

# %%
df[(df['Ranking'] == 443)]
# Out:
#          m/z A        m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 18  348.178404  1139.896002    313432.6     208262.55  183.14002      443
#
#       intensity A   intensity B  line_id  i  ...  charge_A  charge_B  \
# 18  130760.367188  71698.328125        7  1  ...         1         3
#
#     envelope_id_A  envelope_id_B  deconvoluted_mz_A  deconvoluted_mz_B  \
# 18              4             52           346.1713          3417.6723
#
#     monoisotopic_mass_A  monoisotopic_mass_B  isotope_similarity_A  \
# 18              345.164             3416.665                0.9999
#
#     isotope_similarity_B
# 18                0.9913
#
# [1 rows x 28 columns]

# %%
df[(df['Ranking'] == 9)]
# Out:
#           m/z A        m/z B  Covariance  Partial Cov.    Score  Ranking  \
# 190  348.178404  1140.230185   1775340.5     1380546.9  667.229        9
#
#        intensity A  intensity B  line_id  i  ...  charge_A  charge_B  \
# 190  130760.367188   232353.625        5  1  ...         1         3
#
#      envelope_id_A  envelope_id_B  deconvoluted_mz_A  deconvoluted_mz_B  \
# 190              4             52           346.1713          3417.6723
#
#      monoisotopic_mass_A  monoisotopic_mass_B  isotope_similarity_A  \
# 190              345.164             3416.665                0.9999
#
#      isotope_similarity_B
# 190                0.9913
#
# [1 rows x 28 columns]

# %%
df[(df['envelope_id_B'] == 52)][['m/z B', 'intensity B', 'charge_B', 'deconvoluted_mz_B', 'Ranking']]
# Out:
#            m/z B    intensity B  charge_B  deconvoluted_mz_B  Ranking
# 18   1139.896002   71698.328125         3          3417.6723      443
# 147  1140.564372  250522.953125         3          3417.6723        7
# 150  1139.896002   71698.328125         3          3417.6723     1265
# 154  1140.230185  232353.625000         3          3417.6723      521
# 173  1140.898630  156847.343750         3          3417.6723       13
# 174  1140.230185  232353.625000         3          3417.6723      321
# 176  1140.564372  250522.953125         3          3417.6723      205
# 190  1140.230185  232353.625000         3          3417.6723        9
# 194  1139.896002   71698.328125         3          3417.6723      991

# %%
df[(df['envelope_id_A'] == 4)][['m/z A', 'intensity A', 'charge_A', 'deconvoluted_mz_A', 'Ranking']]
# Out:
#           m/z A    intensity A  charge_A  deconvoluted_mz_A  Ranking
# 18   348.178404  130760.367188         1           346.1713      443
# 147  348.178404  130760.367188         1           346.1713        7
# 150  350.183780    1713.923096         1           346.1713     1265
# 154  349.181847   15978.585938         1           346.1713      521
# 173  348.178404  130760.367188         1           346.1713       13
# 174  350.183780    1713.923096         1           346.1713      321
# 176  349.181847   15978.585938         1           346.1713      205
# 190  348.178404  130760.367188         1           346.1713        9
# 194  349.181847   15978.585938         1           346.1713      991

# %%
df[(df['Ranking'] == 37)]
# Out:
#           m/z A        m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 153  477.277555  1097.531602   328248.56     300365.71  494.73448       37
#
#       intensity A    intensity B  line_id  i  ...  charge_A  charge_B  \
# 153  18388.570313  125307.726563        3  1  ...         1         3
#
#      envelope_id_A  envelope_id_B  deconvoluted_mz_A  deconvoluted_mz_B  \
# 153              6             51            477.278          3289.5763
#
#      monoisotopic_mass_A  monoisotopic_mass_B  isotope_similarity_A  \
# 153             476.2707             3288.569                   NaN
#
#      isotope_similarity_B
# 153                0.9918
#
# [1 rows x 28 columns]

# %%
df[(df['envelope_id_B'] == 51)][['m/z B', 'intensity B', 'charge_B', 'deconvoluted_mz_B', 'Ranking']]
# Out:
#            m/z B    intensity B  charge_B  deconvoluted_mz_B  Ranking
# 20   1097.197400   43545.941406         3          3289.5763      101
# 148  1097.197400   43545.941406         3          3289.5763      219
# 151  1097.865943  128894.265625         3          3289.5763        1
# 153  1097.531602  125307.726563         3          3289.5763       37
# 158  1097.865943  128894.265625         3          3289.5763     1059
# 170  1098.199865   74608.390625         3          3289.5763        2
# 172  1097.531602  125307.726563         3          3289.5763      431
# 178  1097.865943  128894.265625         3          3289.5763       90
# 191  1097.531602  125307.726563         3          3289.5763        3
# 192  1097.197400   43545.941406         3          3289.5763       71

# %%
data_path = "/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/deconv/james_result/Covariances_Deisotoped_V1/Covariance_Data_CecropinA_Z6_NCE20_200_ions_Deisotoped_FFC_Sum_Top1000"
df = pd.read_csv(data_path, sep=r"\s+", skiprows=1, header=None, engine="python")
df.columns = ["m/z A", "m/z B","Score", "Ranking"]

# %%
data_path = "/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/deconv/KWK6+NCE20_ffc_loss_annotated.txt"
df = pd.read_csv(data_path, sep="\t", engine="python")

# %%
df[(df['Ranking'] == 41)]
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.     Score  Ranking  \
# 81  217.166711  758.253989   77540.585     43376.331  292.5912       41
#
#      intensity A  intensity B  line_id  i  ...  charge_A  charge_B  \
# 81  25093.941406  47628.65625       12  1  ...         1         5
#
#     envelope_id_A  envelope_id_B  deconvoluted_mz_A  deconvoluted_mz_B  \
# 81              0             42            217.167           3787.241
#
#     monoisotopic_mass_A  monoisotopic_mass_B  isotope_similarity_A  \
# 81             216.1597            3786.2337                   NaN
#
#     isotope_similarity_B
# 81                   NaN
#
# [1 rows x 28 columns]

# %%
df[(df['envelope_id_A'] == 0)][['m/z A', 'intensity A', 'charge_A', 'deconvoluted_mz_A', 'Ranking']]
# Out:
#          m/z A   intensity A  charge_A  deconvoluted_mz_A  Ranking
# 81  217.166711  25093.941406         1            217.167       41

# %%
df[(df['envelope_id_B'] == 42)][['m/z B', 'intensity B', 'charge_B', 'deconvoluted_mz_B', 'Ranking']]
# Out:
#          m/z B  intensity B  charge_B  deconvoluted_mz_B  Ranking
# 81  758.253989  47628.65625         5           3787.241       41

# %%
758.253989 * 5 - 5 + 1
# Out:
# 3787.269945

# %%
3786.241 / 5 + 1
# Out:
# 758.2482

# %%
df[(df['charge_A'] == 5)]
# Out:
# Empty DataFrame
# Columns: [m/z A, m/z B, Covariance, Partial Cov., Score, Ranking, intensity A, intensity B, line_id, i, j, line_offset, matched_offset, line_n_points, is_parental, ffc_index, mz1_A, mz1_B, charge_A, charge_B, envelope_id_A, envelope_id_B, deconvoluted_mz_A, deconvoluted_mz_B, monoisotopic_mass_A, monoisotopic_mass_B, isotope_similarity_A, isotope_similarity_B]
# Index: []
#
# [0 rows x 28 columns]

# %%
test = pd.read_csv('/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/KWK6+NCE20_with_intensity', sep='\t')
test[test['m/z B']== 758.253989][test['Ranking'] < 2000]
# Out:
# /var/folders/rn/8krws_b93vv3ckfsgwjhq5z80000gn/T/ipykernel_4375/958601255.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test[test['m/z B']== 758.253989][test['Ranking'] < 2000]
#              m/z A       m/z B    Covariance  Partial Cov.       Score  \
# 24474   217.166711  758.253989  7.754059e+04  4.337633e+04   292.59120
# 35013   256.166460  758.253989  5.654883e+03  4.328610e+03   162.33451
# 176133  598.563056  758.253989  8.708895e+03  8.053344e+03   158.41256
# 378764  657.736603  758.253989  2.601039e+04  2.202994e+04   161.45664
# 444158  671.357611  758.253989  9.440767e+03  6.792352e+03   179.34895
# 622278  758.253989  758.253989  2.311641e+06  2.236460e+06  2493.10940
#
#         Ranking   intensity A  intensity B
# 24474        41  25093.941406  47628.65625
# 35013      1287    633.179077  47628.65625
# 176133     1564    630.509949  47628.65625
# 378764     1349   3713.942871  47628.65625
# ...

# %%
758.05343800, 758.253989, 758.45466300
# Out:
# (758.053438, 758.253989, 758.454663)

# %%
test[test['m/z B']== 758.05343800][test['Ranking'] < 2000]
# Out:
# /var/folders/rn/8krws_b93vv3ckfsgwjhq5z80000gn/T/ipykernel_4375/3170292459.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test[test['m/z B']== 758.05343800][test['Ranking'] < 2000]
#              m/z A       m/z B   Covariance  Partial Cov.       Score  \
# 228780  618.175189  758.053438    6488.3509     6178.5350   175.18486
# 447825  672.806050  758.053438   11265.9360    10365.4640   173.79386
# 512805  705.676532  758.053438    5835.0158     5575.0817   160.56506
# 587100  744.951930  758.053438   15867.2100    14486.6900   194.55462
# 618351  755.711984  758.053438    9336.9750     8326.1336   167.58404
# 620976  758.053438  758.053438  884205.1000   875217.0900  2150.09560
#
#         Ranking   intensity A   intensity B
# 228780      685    308.560303  19029.416016
# 447825      721   1301.951538  19029.416016
# 512805     1408    710.581665  19029.416016
# 587100      314   2449.152100  19029.416016
# ...

# %%
test[test['m/z B']== 758.45466300][test['Ranking'] < 2000]
# Out:
# /var/folders/rn/8krws_b93vv3ckfsgwjhq5z80000gn/T/ipykernel_4375/1584698635.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   test[test['m/z B']== 758.45466300][test['Ranking'] < 2000]
#              m/z A       m/z B   Covariance  Partial Cov.       Score  \
# 281529  635.990761  758.454663    21344.970     15600.174   157.44523
# 328615  649.996426  758.454663   251268.090    113554.630   205.34192
# 416997  664.903701  758.454663   190510.850     92435.422   157.29297
# 535675  723.936383  758.454663    12119.562     10167.701   173.70168
# 554347  731.196176  758.454663    25572.290     20733.118   156.16581
# 561085  734.446250  758.454663    21341.419     16121.474   217.23942
# 564400  736.238657  758.454663    28306.144     21741.635   171.23843
# 622710  758.454663  758.454663  3019432.300   2794208.500  3014.45420
#
#         Ranking   intensity A   intensity B
# 281529     1633   1460.070801  92884.914063
# ...

# %%
df[(df['Ranking'] == 158)]
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 49  280.182538  862.770331   10941.353     8748.9241  215.47772      158
#
#      intensity A  intensity B  line_id  i  ...  charge_A  charge_B  \
# 49  15539.794922  4408.387207        3  2  ...         2         4
#
#     envelope_id_A  envelope_id_B  deconvoluted_mz_A  deconvoluted_mz_B  \
# 49             13             27            559.358          3444.0476
#
#     monoisotopic_mass_A  monoisotopic_mass_B  isotope_similarity_A  \
# 49             558.3507            3443.0404                0.9955
#
#     isotope_similarity_B
# 49                 0.986
#
# [1 rows x 28 columns]

# %%
df[(df['Ranking'] == 7)]
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 17  280.182538  862.519546   44636.806     37949.677  438.38307        7
#
#      intensity A   intensity B  line_id  i  ...  charge_A  charge_B  \
# 17  15539.794922  15941.132813        0  2  ...         2         4
#
#     envelope_id_A  envelope_id_B  deconvoluted_mz_A  deconvoluted_mz_B  \
# 17             13             27            559.358          3444.0476
#
#     monoisotopic_mass_A  monoisotopic_mass_B  isotope_similarity_A  \
# 17             558.3507            3443.0404                0.9955
#
#     isotope_similarity_B
# 17                 0.986
#
# [1 rows x 28 columns]

# %%
280.182538	* 2 + 862.519546 * 4
# Out:
# 4010.44326

# %%
df[(df['envelope_id_A'] == 13)][['m/z A', 'intensity A', 'charge_A', 'deconvoluted_mz_A', 'Ranking']]
# Out:
#          m/z A   intensity A  charge_A  deconvoluted_mz_A  Ranking
# 5   280.182538  15539.794922         2            559.358      222
# 17  280.182538  15539.794922         2            559.358        7
# 19  281.185473    473.147644         2            559.358      889
# 31  280.182538  15539.794922         2            559.358        3
# 33  280.684175   3396.115479         2            559.358      193
# 41  280.182538  15539.794922         2            559.358        4
# 45  280.684175   3396.115479         2            559.358       75
# 49  280.182538  15539.794922         2            559.358      158
# 50  280.684175   3396.115479         2            559.358      303

# %%
df[(df['envelope_id_B'] == 27)][['m/z B', 'intensity B', 'charge_B', 'deconvoluted_mz_B', 'Ranking']]
# Out:
#          m/z B   intensity B  charge_B  deconvoluted_mz_B  Ranking
# 5   861.767638  11347.268555         4          3444.0476      222
# 17  862.519546  15941.132813         4          3444.0476        7
# 19  862.018239  26861.677734         4          3444.0476      889
# 31  862.268876  25143.320313         4          3444.0476        3
# 33  862.018239  26861.677734         4          3444.0476      193
# 41  862.018239  26861.677734         4          3444.0476        4
# 45  861.767638  11347.268555         4          3444.0476       75
# 49  862.770331   4408.387207         4          3444.0476      158
# 50  862.519546  15941.132813         4          3444.0476      303

# %%
data_path = "/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/deconv/KWK6+NCE20_ffc_loss_annotated.txt"
df = pd.read_csv(data_path, sep="\t", engine="python")

# %%
data_path = "/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/deconv/KWK6+NCE20_ffc_loss_replaced.txt"
df_test = pd.read_csv(data_path, sep="\t", engine="python")

# %%
df[(df['Ranking'] == 41)]
# Out:
#           m/z A       m/z B  Covariance  Partial Cov.     Score  Ranking  \
# 101  217.166711  758.253989   77540.585     43376.331  292.5912       41
#
#       intensity A  intensity B  line_id  i  ...  charge_A  charge_B  \
# 101  25093.941406  47628.65625        8  1  ...         1         5
#
#      envelope_id_A  envelope_id_B  deconvoluted_mz_A  deconvoluted_mz_B  \
# 101              0             64           217.1667          3785.2341
#
#      monoisotopic_mass_A  monoisotopic_mass_B  isotope_similarity_A  \
# 101             216.1594            3784.2268                 0.999
#
#      isotope_similarity_B
# 101                0.9239
#
# [1 rows x 28 columns]

# %%
df[(df['Ranking'] == 6586)]
# Out:
#         m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 9  217.166711  758.053438    23425.76      11613.02  127.24412     6586
#
#     intensity A   intensity B  line_id  i  ...  charge_A  charge_B  \
# 9  25093.941406  19029.416016       13  1  ...         1         5
#
#    envelope_id_A  envelope_id_B  deconvoluted_mz_A  deconvoluted_mz_B  \
# 9              0             64           217.1667          3785.2341
#
#    monoisotopic_mass_A  monoisotopic_mass_B  isotope_similarity_A  \
# 9             216.1594            3784.2268                 0.999
#
#    isotope_similarity_B
# 9                0.9239
#
# [1 rows x 28 columns]

# %%
df[(df['Ranking'] == 6846)]
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 89  217.166711  758.655175   39531.952     15088.433  126.44845     6846
#
#      intensity A   intensity B  line_id  i  ...  charge_A  charge_B  \
# 89  25093.941406  34920.109375        6  1  ...         1         5
#
#     envelope_id_A  envelope_id_B  deconvoluted_mz_A  deconvoluted_mz_B  \
# 89              0             64           217.1667          3785.2341
#
#     monoisotopic_mass_A  monoisotopic_mass_B  isotope_similarity_A  \
# 89             216.1594            3784.2268                 0.999
#
#     isotope_similarity_B
# 89                0.9239
#
# [1 rows x 28 columns]

# %%
df[(df['envelope_id_B'] == 64)][['m/z B', 'intensity B', 'charge_B', 'deconvoluted_mz_B', 'Ranking']]
# Out:
#           m/z B   intensity B  charge_B  deconvoluted_mz_B  Ranking
# 9    758.053438  19029.416016         5          3785.2341     6586
# 89   758.655175  34920.109375         5          3785.2341     6846
# 101  758.253989  47628.656250         5          3785.2341       41
# 102  758.053438  19029.416016         5          3785.2341     3449

# %%
df_test[df_test['Ranking'] == 6586]
# Out:
#        m/z A      m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 9  217.16668  757.85264    23425.76      11613.02  127.24412     6586
#
#     intensity A   intensity B  line_id
# 9  25093.941406  19029.416016       13

# %%
758*5
# Out:
# 3790

# %%
df_test[df_test['Ranking'] == 6586]
# Out:
#        m/z A      m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 9  217.16668  757.85264    23425.76      11613.02  127.24412     6586
#
#     intensity A   intensity B  line_id
# 9  25093.941406  19029.416016       13

# %%
758.65522*5+217.16698
# Out:
# 4010.44308

# %%
df[df['envelope_id_A'] ==51]
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 78  618.778296  915.546968   55952.174     27991.914  150.51724     2208
#
#      intensity A   intensity B  line_id  i  ...  charge_A  charge_B  \
# 78  87621.890625  10809.333008        5  5  ...         5         1
#
#     envelope_id_A  envelope_id_B  deconvoluted_mz_A  deconvoluted_mz_B  \
# 78             51             18           3089.862            914.545
#
#     monoisotopic_mass_A  monoisotopic_mass_B  isotope_similarity_A  \
# 78            3088.8547             913.5377                   NaN
#
#     isotope_similarity_B
# 78                0.9994
#
# [1 rows x 28 columns]

# %%
df[df['envelope_id_A'] ==52]
# Out:
#           m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 106  619.379952  914.545015   22717.255     16610.126  188.38862      392
#
#      intensity A   intensity B  line_id  i  ...  charge_A  charge_B  \
# 106  9488.717773  22885.527344        9  5  ...         5         1
#
#      envelope_id_A  envelope_id_B  deconvoluted_mz_A  deconvoluted_mz_B  \
# 106             52             18           3092.871            914.545
#
#      monoisotopic_mass_A  monoisotopic_mass_B  isotope_similarity_A  \
# 106            3091.8637             913.5377                   NaN
#
#      isotope_similarity_B
# 106                0.9994
#
# [1 rows x 28 columns]

# %%
df_test[df_test['Ranking'] == 6586]
# Out:
#        m/z A      m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 9  217.16698  757.85268    23425.76      11613.02  127.24412     6586
#
#     intensity A   intensity B  line_id
# 9  25093.941406  19029.416016       13

# %%
619.379952 * 5
# Out:
# 3096.8997600000002

# %%
618.778296	* 5
# Out:
# 3093.89148

# %%
DATA_PATH = (
    "/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/"
    "KWK6+NCE20_with_intensity"
)
df = pd.read_csv(DATA_PATH, sep="\t", skiprows=1, header=None, engine="python")
df.columns = [
    "m/z A", "m/z B", "Covariance", "Partial Cov.",
    "Score", "Ranking", "intensity A", "intensity B",
]
df = df[df["Ranking"] != -1].sort_values("Ranking").head(8000)

# %%
df.to_csv('/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/KWK6+NCE20_with_intensity_top_8000', sep='\t', index=False)

# %%
DATA_PATH = (
    "/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/"
    "LLG6+_with_intensity"
)
df = pd.read_csv(DATA_PATH, sep="\t", skiprows=1, header=None, engine="python")
df.columns = [
    "m/z A", "m/z B", "Covariance", "Partial Cov.",
    "Score", "Ranking", "intensity A", "intensity B",
]
df = df[df["Ranking"] != -1].sort_values("Ranking").head(8000)
df.to_csv('/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/LLG6+_with_intensity_top_8000', sep='\t', index=False)

# %%
import pandas as pd

# Your exact file path
DATA_PATH = "/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/LLG6+_with_intensity_top_8000"

# Load the data exactly how your main script does
df = pd.read_csv(DATA_PATH, sep="\t", skiprows=1, header=None, engine="python")
df.columns = [
    "m/z A", "m/z B", "Covariance", "Partial Cov.",
    "Score", "Ranking", "intensity A", "intensity B",
]

# Check for missing values (NaNs)
missing_a = df["intensity A"].isna().sum()
missing_b = df["intensity B"].isna().sum()

print(f"Total rows in dataset: {len(df)}")
print("-" * 30)
print(f"Missing values in 'intensity A': {missing_a}")
print(f"Missing values in 'intensity B': {missing_b}")
print("-" * 30)

# If there are missing values, show the first few rows where they happen
if missing_a > 0 or missing_b > 0:
    print("Here are the first few rows with missing intensities:")
    bad_rows = df[df["intensity A"].isna() | df["intensity B"].isna()]
    print(bad_rows[["m/z A", "m/z B", "intensity A", "intensity B", "Ranking"]].head())
else:
    print("No missing values found! The issue might be coming from upstream data processing.")
# Out:
# Total rows in dataset: 8000
# ------------------------------
# Missing values in 'intensity A': 1
# Missing values in 'intensity B': 157
# ------------------------------
# Here are the first few rows with missing intensities:
#           m/z A        m/z B   intensity A  intensity B  Ranking
# 56   657.586985  1192.688184   5420.193359          NaN       57
# 67   240.134815  1193.690886   8916.949219          NaN       68
# 69   635.380298  1321.730892   5843.664551          NaN       70
# 114  793.473007  1208.646201  32277.076172          NaN      115
# 147  240.134815  1192.688184   8916.949219          NaN      148

# %%
DATA_PATH = "/Users/kevinmbp/Desktop/2D_spec_dict/data/short_peptide/YLE3+.txt"
df = pd.read_csv(DATA_PATH, sep=r"\s+", skiprows=1, header=None, engine="python")
df.columns = ["m/z A", "m/z B", "Covariance", "Partial Cov.", "Score", "Ranking"]

# %%
df[(df['m/z A'] == 939.450318) & (df['m/z B'] == 473.796722)]
# Out:
#             m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking
# 75792  939.450318  473.796722   1492357.9     1446835.7  199.11685      284

# %%
df[(df['Ranking'] == 35)]
# Out:
#             m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking
# 16668  509.315401  868.412412   5171550.2     5130640.1  444.21576       35
# 72633  868.412412  509.315401   5171550.2     5130640.1  444.21576       35

# %%
import pandas as pd

path = '/Users/kevinmbp/Desktop/2D_spec_dict/data/virtual_MSMS/VEADIAGHGQEVLIR-mz536-z3_Intensity_Sum'

# 1. Read the spectral file with the custom split to keep annotations intact
with open(path, 'r') as f:
    data = [line.strip().split(None, 3) for line in f if line.strip()]

# 2. Create the spectral DataFrame
df_msms = pd.DataFrame(data, columns=["intensity", "mz", "error", "annotation"])

# 3. Convert columns to numeric types
df_msms["mz"] = pd.to_numeric(df_msms["mz"], errors="coerce")
df_msms["intensity"] = pd.to_numeric(df_msms["intensity"], errors="coerce")
df_msms["error"] = pd.to_numeric(df_msms["error"], errors="coerce")

# 4. Clean up NaNs and sort by m/z (required for merge_asof)
df_msms = df_msms.dropna(subset=["mz", "intensity"]).sort_values("mz").reset_index(drop=True)

# --- Process MMS File ---
mss_input_file = "/Users/kevinmbp/Desktop/2D_spec_dict/data/short_peptide/VEA3+.txt"
mms_df = pd.read_csv(
    mss_input_file,
    sep=r"\s+",
    skiprows=1,
    header=None,
    engine="python"
)

mms_df.columns = ["m/z A", "m/z B", "Covariance", "Partial Cov.", "Score", "Ranking"]
mms_df["m/z A"] = pd.to_numeric(mms_df["m/z A"], errors="coerce")
mms_df["m/z B"] = pd.to_numeric(mms_df["m/z B"], errors="coerce")
tolerance = 0.001

# -------- Match for m/z A --------
a_df = mms_df[["m/z A"]].copy().sort_values("m/z A").reset_index()
a_matched = pd.merge_asof(
    a_df,
    df_msms,
    left_on="m/z A",
    right_on="mz",
    direction="nearest",
    tolerance=tolerance
)
# Rename intensity, annotation, and error for A
a_matched = a_matched.rename(columns={
    "intensity": "intensity A", 
    "annotation": "annotation A",
    "error": "error A"
})
a_matched = a_matched.set_index("index")

# -------- Match for m/z B --------
b_df = mms_df[["m/z B"]].copy().sort_values("m/z B").reset_index()
b_matched = pd.merge_asof(
    b_df,
    df_msms,
    left_on="m/z B",
    right_on="mz",
    direction="nearest",
    tolerance=tolerance
)
# Rename intensity, annotation, and error for B
b_matched = b_matched.rename(columns={
    "intensity": "intensity B", 
    "annotation": "annotation B",
    "error": "error B"
})
b_matched = b_matched.set_index("index")

# -------- Final Join --------
# Add all matched columns back to the original MMS dataframe
mms_df["intensity A"] = a_matched["intensity A"]
mms_df["annotation A"] = a_matched["annotation A"]
mms_df["error A"] = a_matched["error A"]

mms_df["intensity B"] = b_matched["intensity B"]
mms_df["annotation B"] = b_matched["annotation B"]
mms_df["error B"] = b_matched["error B"]

mms_df.head()
# Out:
#         m/z A       m/z B   Covariance  Partial Cov.        Score  Ranking  \
# 0  156.102426  156.102426  25073159.00  2.503813e+07  1604.311900       -1
# 1  156.102426  175.119605   1766662.60  1.577744e+06   183.251870      282
# 2  156.102426  183.113388   1159704.90  9.680421e+05   139.187240      740
# 3  156.102426  187.072039    116453.27  9.340415e+04    28.558445     4715
# 4  156.102426  195.088350   -310522.16 -3.434978e+05  -186.746850    13511
#
#    intensity A annotation A  error A  intensity B  \
# 0   968.253174     No Match  -1000.0   968.253174
# 1   968.253174     No Match  -1000.0  8633.249023
# 2   968.253174     No Match  -1000.0  6728.792969
# 3   968.253174     No Match  -1000.0   973.557800
# 4   968.253174     No Match  -1000.0  1063.230103
#
#                                         annotation B      error B
# 0                                           No Match -1000.000000
# 1                                            y1 (+1)    -0.000653
# ...

# %%
df = pd.read_csv('/Users/kevinmbp/Desktop/2D_spec_dict/pepline/protein_result.csv')
df.head()
# Out:
#    Unnamed: 0       m/z A       m/z B  Ranking  selected_total  component_x1  \
# 0         539  666.352264  610.345257        1     1887.042778    666.352264
# 1         538  610.345257  666.352264        1     1887.042778   1220.690514
# 2         543  740.422212  406.198635        3     1887.043059   1480.844424
# 3         542  406.198635  740.422212        3     1887.043059    406.198635
# 4          29  406.198635  740.923736        5     1888.046107    406.198635
#
#    component_x2  charge_A  charge_B   adj_mass_A  ...  theoretical_mass_A  \
# 0   1220.690514         1         2   666.352264  ...           666.34970
# 1    666.352264         2         1  1219.682674  ...          1219.67929
# 2    406.198635         2         1  1479.836584  ...          1479.83176
# 3   1480.844424         1         2   406.198635  ...           406.19723
# 4   1481.847472         1         2   406.198635  ...           406.19723
#
# ...

# %%
df[(df['m/z A'] <= 277.155512 + 1) & (df['m/z A'] >= 277.155512 - 1)]
# Out:
#      Unnamed: 0       m/z A        m/z B  Ranking  selected_total  \
# 82          569  277.119219  1332.771603      221     1887.010041
# 272         201  278.122393  1332.771603     5378     1889.016389
# 298         304  277.119219   806.448417     6078     1890.016053
# 456         580  278.122393   804.439021    10397     1887.000435
#
#      component_x1  component_x2  charge_A  charge_B  adj_mass_A  ...  \
# 82     554.238438   1332.771603         2         1  553.230598  ...
# 272    556.244786   1332.771603         2         1  555.236946  ...
# 298    277.119219   1612.896834         1         2  277.119219  ...
# 456    278.122393   1608.878042         1         2  278.122393  ...
#
#      theoretical_mass_A iso_A  base_name_A  explanation_B  deviation_B  \
# 82            553.26564   0.0           b4            0.0     0.008253
# 272           555.27234   2.0           b4            0.0     0.008253
# 298           277.15464   0.0           b2            3.0     0.004594
# ...

# %%
partitioned = pd.read_csv('/Users/kevinmbp/Desktop/2D_spec_dict/pepline/partitioned.csv')

# %%
partitioned[partitioned['Ranking'] ==16002]
# Out:
#        Unnamed: 0       m/z A       m/z B  Covariance  Partial Cov.     Score  \
# 32002       51176  732.392236  776.423518   82122.973     30501.843  5.421271
# 32003       57777  776.423518  732.392236   82122.973     30501.843  5.421271
#
#        Ranking  comp_1_m/z A  comp_2_m/z B  1*m/z A + 2*m/z B  comp_2_m/z A  \
# 32002    16002    732.392236   1552.847036        2285.239272   1464.784472
# 32003    16002    776.423518   1464.784472        2241.207990   1552.847036
#
#        comp_1_m/z B  2*m/z A + 1*m/z B  1*m/z A + 1*m/z B
# 32002    776.423518        2241.207990        1508.815754
# 32003    732.392236        2285.239272        1508.815754

# %%
import pandas as pd
df_entire = pd.read_csv('/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/deconv/KWK6+NCE20_combine_annotated.txt', sep="\t")

# %%
d = df_entire.loc[df_entire["Ranking"] == 44, "envelope_members_A"].iloc[0]
d
# Out:
# '{1083.6566: 6416.47, 1084.6508: 1267.36, 1085.66: 2009.58}'

# %%
542.829029 * 2
# Out:
# 1085.658058

# %%
df_entire.loc[df_entire["Ranking"] == 54]
# Out:
#         m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 2  542.829029  730.444069   5455.7195     5307.2863  261.91906       54
#
#    intensity A  intensity B  line_id  i  ...  envelope_id_A  envelope_id_B  \
# 2  1267.356201  6645.418457        4  2  ...             21             24
#
#    deconvoluted_mz_A  deconvoluted_mz_B  monoisotopic_mass_A  \
# 2          1083.6566           2918.755            1082.6494
#
#    monoisotopic_mass_B  isotope_similarity_A  isotope_similarity_B  \
# 2            2917.7477                0.9345                 0.984
#
#                                   envelope_members_A  \
# 2  {1083.6566: 6416.47, 1084.6508: 1267.36, 1085....
#
#                                   envelope_members_B
# 2  {2917.7516: 624.3, 2918.7544: 6645.42, 2919.75...
#
# [1 rows x 30 columns]

# %%
df_entire.loc[df_entire["Ranking"] == 54]

# %%
df_entire.loc[df_entire["Ranking"] == 44]
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 33  542.829029  730.945574   7052.5846     6790.7505  285.13387       44
#
#     intensity A  intensity B  line_id  i  ...  envelope_id_A  envelope_id_B  \
# 33  1267.356201  8597.196289        1  2  ...             21             24
#
#     deconvoluted_mz_A  deconvoluted_mz_B  monoisotopic_mass_A  \
# 33          1083.6566           2918.755            1082.6494
#
#     monoisotopic_mass_B  isotope_similarity_A  isotope_similarity_B  \
# 33            2917.7477                0.9345                 0.984
#
#                                    envelope_members_A  \
# 33  {1083.6566: 6416.47, 1084.6508: 1267.36, 1085....
#
#                                    envelope_members_B
# 33  {2917.7516: 624.3, 2918.7544: 6645.42, 2919.75...
#
# [1 rows x 30 columns]

# %%
542.829029 - 542.331965
# Out:
# 0.49706400000002304

# %%
543.333648 - 542.829029
# Out:
# 0.5046190000000479

# %%
df_entire.loc[df_entire["envelope_id_A"] == 21]
# Out:
#          m/z A       m/z B  Covariance  Partial Cov.      Score  Ranking  \
# 2   542.829029  730.444069   5455.7195     5307.2863  261.91906       54
# 33  542.829029  730.945574   7052.5846     6790.7505  285.13387       44
# 46  542.829029  730.695037   6368.3143     6030.2876  281.13658       48
#
#     intensity A   intensity B  line_id  i  ...  envelope_id_A  envelope_id_B  \
# 2   1267.356201   6645.418457        4  2  ...             21             24
# 33  1267.356201   8597.196289        1  2  ...             21             24
# 46  1267.356201  10782.216797        2  2  ...             21             24
#
#     deconvoluted_mz_A  deconvoluted_mz_B  monoisotopic_mass_A  \
# 2           1083.6566           2918.755            1082.6494
# 33          1083.6566           2918.755            1082.6494
# 46          1083.6566           2918.755            1082.6494
#
#     monoisotopic_mass_B  isotope_similarity_A  isotope_similarity_B  \
# ...

# %%
730.945574 - 730.444069
# Out:
# 0.5015049999999519

# %%
df_ori = pd.read_csv('/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/KWK6+NCE20_with_intensity', sep = '\t')

# %%
df_ori[df_ori['intensity B'] == 1267.356201].sort_values('Ranking')
# Out:
#              m/z A       m/z B   Covariance  Partial Cov.      Score  Ranking  \
# 146028  542.829029  542.829029  22620.62400   22593.87100  928.73628       -1
# 16768   199.144796  542.829029    676.81033     652.06221  193.20651      329
# 25014   218.170034  542.829029    800.55244     778.06441  166.28231     1056
# 140683  525.268941  542.829029    508.04116     496.10297  157.59689     1621
# 93684   400.229777  542.829029   1310.70340    1145.54870  120.14698     9125
# ...            ...         ...          ...           ...        ...      ...
# 129918  480.314551  542.829029   -229.64633    -238.53747 -182.85839   630572
# 71194   358.173363  542.829029   -286.94065    -305.04451 -199.11943   636760
# 12034   174.124342  542.829029   -725.00968    -816.10652 -200.59817   637233
# 90336   399.236273  542.829029  -1316.90990   -1451.16340 -208.65947   639774
# 56361   307.689681  542.829029   -337.23064    -350.07322 -226.29186   644607
#
#         intensity A  intensity B
# ...

# %%
df_ori[df_ori['intensity B'] == 6416.469727].sort_values('Ranking')
# Out:
#              m/z A       m/z B   Covariance  Partial Cov.       Score  \
# 144960  542.331965  542.331965  69082.42800   67911.72100  2203.92490
# 32042   240.098708  542.331965    673.10648     593.46613   177.46231
# 25013   218.170034  542.331965   1203.41180    1054.65090   156.12509
# 86978   391.214781  542.331965    945.59691     836.08859   155.16982
# 126668  460.316229  542.331965    517.14924     460.75834   125.11324
# ...            ...         ...          ...           ...         ...
# 120143  458.277432  542.331965   -951.85634   -3272.00760  -126.91124
# 125583  459.313668  542.331965   -720.81252   -1433.77420  -129.55325
# 45992   280.684175  542.331965   -928.05617   -1758.41870  -151.77257
# 106985  440.257334  542.331965   -608.76547    -704.18945  -178.98437
# 105882  416.266767  542.331965   -606.45445    -677.30502  -200.54231
#
#         Ranking   intensity A  intensity B
# 144960       -1   6416.469727  6416.469727
# ...

# %%
df_ori[df_ori['intensity B'] == 2009.57666].sort_values('Ranking')
# Out:
#              m/z A       m/z B   Covariance  Partial Cov.       Score  \
# 147095  543.333648  543.333648  23984.24100   23906.77800  1381.98350
# 32044   240.098708  543.333648    472.19110     451.70508   163.68855
# 21487   212.103709  543.333648    474.50693     419.04497   124.50275
# 92570   399.737659  543.333648    822.79543     732.88036   120.11895
# 28534   230.114390  543.333648   1091.24670     882.60568   114.46740
# ...            ...         ...          ...           ...         ...
# 115775  449.764126  543.333648   -850.30535   -1035.92330  -138.46388
# 116869  450.265532  543.333648   -445.57917    -466.99205  -148.64011
# 133159  486.277104  543.333648   -293.91288    -332.62063  -148.64986
# 64370   316.704097  543.333648   -283.22539    -309.88343  -179.06860
# 106987  440.257334  543.333648   -312.08632    -336.63238  -179.07565
#
#         Ranking  intensity A  intensity B
# 147095       -1  2009.576660   2009.57666
# ...

# %%
542.331965	* 2
# Out:
# 1084.66393
