# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/Users/kevinmbp/Desktop/2D_spec_dict/data/long_peptide/Covariance_Data_Myoglobin_Z19_NCE35_250_ions_2000Fragments",
    sep=r"\s+",          # any whitespace
    skiprows=1,          
    header=None,
    engine="python"
)
df.columns = ['m/z A', 'm/z B', 'Covariance', 'Partial Cov.', 'Score', 'Ranking']

# %%
df_mms = df

# %%
df_msms = pd.read_csv('/Users/kevinmbp/Desktop/2D_spec_dict/data/virtual_MSMS/Myoglobin-Z19_NCE35_250_ions_2000_Fragments_Intensity_Sum')

# %%
df_msms
# Out:
#      13322.98730500        657.35756800         -0.00290951   y17 (+3)
# 0           15047.03613300        657.69163800      ...
# 1           18796.29101600        662.86956400      ...
# 2           14076.28222700        663.37064800      ...
# 3           35419.54296900        726.77001500      ...
# 4           66890.50781300        726.97048200      ...
# ...                                                 ...
# 1961        13321.45312500       1021.82387000      ...
# 1962        17481.37109400       1021.97435400      ...
# 1963        19223.74804700       1106.54250800      ...
# 1964        23419.22265600       1107.04358000      ...
# 1965        14950.84277300       1107.54513500      ...
#
# [1966 rows x 1 columns]
